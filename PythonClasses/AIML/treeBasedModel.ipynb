# %%
# %pip install graphviz
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, classification_report,confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_curve,roc_auc_score
from sklearn.linear_model import ElasticNet,Lasso,Ridge
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import mutual_info_regression, SelectKBest
from scipy import stats
from sklearn.feature_selection import f_regression
from sklearn.datasets import load_breast_cancer
from collections import Counter
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.dummy import DummyClassifier
from sklearn.dummy import DummyClassifier
import graphviz
import math

# %%
# Entropi

# e = -1 (0.4)* - 1.3219 - (0.6)* - 0.7369
# print(e)

# print((0.4)* - 1.3219)
# print((0.6)* - 0.7369)

# df = pd.DataFrame(data)

# X = pd.get_dummies(df.drop("PlayTennis", axis=1), drop_first=True)
# y = df["PlayTennis"].map({"No": 0, "Yes": 1})
# X

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42, stratify=y
# )

# %%
# data = {
#     'Outlook': ['Sunny','Sunny','Overcast','Rain','Rain','Rain','Overcast','Sunny','Sunny','Rain','Sunny','Overcast','Overcast','Rain'],
#     'Temperature': ['Hot','Hot','Hot','Mild','Cool','Cool','Cool','Mild','Cool','Mild','Mild','Mild','Hot','Mild'],
#     'Humidity': ['High','High','High','High','Normal','Normal','Normal','High','Normal','Normal','Normal','High','Normal','High'],
#     'Wind': ['Weak','Strong','Weak','Weak','Weak','Strong','Strong','Weak','Weak','Weak','Strong','Strong','Weak','Strong'],
#     'PlayTennis': ['No','No','Yes','Yes','Yes','No','Yes','No','Yes','Yes','Yes','Yes','Yes','No']
# }

# df = pd.DataFrame(data)

# le = LabelEncoder()

# df = df.apply(le.fit_transform)

# X = df.drop(['PlayTennis'], axis=1)
# y = df['PlayTennis']

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# model = DecisionTreeClassifier(criterion='gini',max_depth=3)

# model.fit(X_train,y_train)

# y_pred = model.predict(X_test)


# y_pred = model.predict(X_test)
# print("Train acc:", model.score(X_train, y_train))
# print("Test  acc:", accuracy_score(y_test, y_pred))
# fir, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=200)

# tree.plot_tree(model)

# %%
df = pd.read_csv('../../Datasets/fromclass/cleaned_df_balanced.csv')

x = df.drop(['Unnamed: 0','target'], axis=1)
y = df['target']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,random_state=42)

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)
# dummy_clf = DummyClassifier()
tree = LogisticRegression()

tree.fit(x_train,y_train)
ypred_log = tree.predict(x_test)

#metrix
accuracy_log = accuracy_score(y_test,ypred_log)
f1score_log = f1_score(y_test,ypred_log)
confMetrix_log = confusion_matrix(y_test,ypred_log)

print(f'accuracy Score : {accuracy_log}')
print(f'F1 Score : {f1score_log}')
print('-**-**-'*8)
print(f'Confuision metrix')
print(confMetrix_log)
print('-**-**-'*8)
print(classification_report(y_test, ypred_log))
# lr = DecisionTreeClassifier(criterion='entropy')

# lr.fit(x_train, y_train)
# Out:
# accuracy Score : 0.7540983606557377
# F1 Score : 0.7540983606557377
# -**-**--**-**--**-**--**-**--**-**--**-**--**-**--**-**-
# Confuision metrix
# [[23 12]
#  [ 3 23]]
# -**-**--**-**--**-**--**-**--**-**--**-**--**-**--**-**-
#               precision    recall  f1-score   support
#
#            0       0.88      0.66      0.75        35
#            1       0.66      0.88      0.75        26
#
#     accuracy                           0.75        61
#    macro avg       0.77      0.77      0.75        61
# weighted avg       0.79      0.75      0.75        61

# %%
df = pd.read_csv('../../Datasets/fromclass/cleaned_df_balanced.csv')

x = df.drop(['Unnamed: 0','target'], axis=1)
y = df['target']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,random_state=42)

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

tree = DecisionTreeClassifier()

tree.fit(x_train,y_train)
ypred = tree.predict(x_test)

#metrix
accuracy = accuracy_score(y_test,ypred)
f1score = f1_score(y_test,ypred)
confMetrix = confusion_matrix(y_test,ypred)

print(f'accuracy Score : {accuracy}')
print(f'F1 Score : {f1score}')
print('-**-**-'*8)
print(f'Confuision metrix')
print(confMetrix)
print('-**-**-'*8)
print(classification_report(y_test, ypred))


model_ev = pd.DataFrame({'Model': ['Logistic Regression', 'Decision Tree'],
                         'Accuracy':[accuracy_log, accuracy],
                         'f1 Score':[f1score_log, f1score]})

model_ev

fpr_log, tpr_log, thresholds_log = roc_curve(y_test,ypred_log)
fpr_tree, tpr_tree, thresholds_tree = roc_curve(y_test,ypred)

plt.plot([0,1],[0,1], 'r--')
plt.plot(fpr_log,tpr_log,label='Logistic Regression')
plt.plot(fpr_tree,tpr_tree,label='Decision Tree')
plt.title('Logistic Regression, Decision Tree')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend(loc='best')
# Out:
# accuracy Score : 0.5901639344262295
# F1 Score : 0.5614035087719298
# -**-**--**-**--**-**--**-**--**-**--**-**--**-**--**-**-
# Confuision metrix
# [[20 15]
#  [10 16]]
# -**-**--**-**--**-**--**-**--**-**--**-**--**-**--**-**-
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62        35
#            1       0.52      0.62      0.56        26
#
#     accuracy                           0.59        61
#    macro avg       0.59      0.59      0.59        61
# weighted avg       0.60      0.59      0.59        61
