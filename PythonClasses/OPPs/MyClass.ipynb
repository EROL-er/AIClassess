# %%
class Dog:
    def __init__(self, name, color, type):
        self.name=name
        self.color=color
        self.type=type

class People:
    def __init__(self):
        self.names = []


    def add_person(self, name,):
        self.names.append(name)
        return name

group = People()
x=group.add_person("Erol")    
y=group.add_person("Desak")   


mydog= Dog("Resho","Black","BoolDog")
YourDog= Dog("Besho","White","Chivava")


def info(owner, dog):
    print(owner,dog)

info(f"{y} has a dog and it's name is {YourDog.name} and her",f'dog color is {YourDog.color} ' f"and it's type is {YourDog.type}")
# Out:
# Desak has a dog and it's name is Besho and her dog color is White and it's type is Chivava
