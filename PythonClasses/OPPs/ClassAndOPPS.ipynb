# %%
#A class to handle deposits and withdrwawals from a bank

import sys
class Bank(object):
  """Bank related transdactions"""
  #to initialize name and balance instance variales

  def __init__(self, name,balance=0.0):
    self.name = name
    self.balance = balance

    #to add deposit amount to existing balance
  def deposit(self, amout):
      self.balance +=amout
      return self.balance
  

  def withdraw(self,amout):
        
        if amout > self.balance:
         print("Low balance, can't withdraw the given amout")
        else:
          self.balance -=amout
        return self.balance
  


    #using the Bank class
    #Create an account with the given name and balance 0.00

# b = Bank("Erol",120.00)
# print("Welcome to the bank Mr.",b.name, ". Your balance is $",b.balance)
# c = Bank("Desak",130.00)
# print("Welcome to the bank Mr.",c.name, ". Your balance is $",c.balance)
# w = b.withdraw(50)
# q = c.withdraw(5)
# print("Your balance after withdraw is $",w)
# print("Your balance after withdraw is $",q)

# import datetime
# datetime.datetime.day

# print("Current date and time : ")
# print (datetime.datetime.today())

x = [1,2,3,4,5,6]

for y in x:
    if 1 in x:
      print(y)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
