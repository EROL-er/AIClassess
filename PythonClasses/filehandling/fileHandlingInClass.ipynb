# %%
with open('../textFiles/wrtieTofile.csv','w') as file:
  
  name_list = ['Malcom X', 'Martin Luther King', 'Nelson Mandela']
  age_list = [39, 39, 95]
  city_list = ['New York', 'Atlanta', 'Johannesburg']
  email_list = [name.split()[0].lower() + '@mail.com' for name in name_list]
  phone_list = ['111-222-3333', '444-555-6666', '777-888-9999']
  list_of_fruits = ['banana','Apple', 'Banana']
  file.write("""Name,Age,City,Email,Phone,Likes\n""")
  for i in range(len(name_list)):
    file.write(f"{name_list[i]},{age_list[i]},{city_list[i]},{email_list[i]},{phone_list[i]},{list_of_fruits[i]}\n")


with open('../textFiles/wrtieTofile.csv', 'r') as ReadFile:
    content = ReadFile.read()

with open('../textFiles/newFile.csv', 'w') as writeToFile:
    for line in content.split('\n'):
        contents = line.split(',')
        if len(contents) > 1:
            # join items back into comma-separated string
            row = ','.join(contents)
            writeToFile.write(str(contents) + '\n')
