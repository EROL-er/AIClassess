# %%
f= open('../textFiles/myfile2.csv','w')

List_of_fruits = ['FRUITS','Apple', 'Banana', 'Cherry', 'Date', 'Elderberry', 'Fig', 'Grape', 'Honeydew', 'Indian Fig', 'Jackfruit', 'Kiwi', 'Lemon', 'Mango', 'Nectarine', 'Orange', 'Papaya', 'Quince', 'Raspberry', 'Strawberry', 'Tangerine', 'Ugli fruit', 'Vanilla Bean', 'Watermelon', 'Xigua', 'Yellow Passion Fruit', 'Zucchini']
#enter text
str=""
for fruit in List_of_fruits:
    str=str+fruit+"\n"
#write text to file
f.write(str)
#close file
f.close()

# %%
#open file in read mode
f = open('../textFiles/myfile1.txt', 'r')

n = len(f.readlines())
content = f.read()
print("Number of lines in the file: ", n)

f.close()
# Out:
# Number of lines in the file:  26

# %%
# Error handling
try:
    f=open('../textFiles/myfile1.txt','r')
    content=f.read()
    print(content)
except FileNotFoundError:
    print("File not found please check the file path",f.name)
except Exception as e:
    print("An error occurred: ",e)
finally:
    f.close()
# Out:
# File not found please check the file path ../textFiles/myfile1.txt
