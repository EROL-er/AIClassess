# %%
try:
    date = eval(input("Enter a date: "))
except SyntaxError:
    print("Invalid date")
except NameError:
    print("Invalid date")
else:
    print("Valid date", date)
finally:
    print("Execution completed")
# Out:
# Valid date 2025
# Execution completed
