# %% [markdown]
# # Fist class of Numpy

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5],dtype='i')
type(arr)
# Out:
# numpy.ndarray

# %%
# a = np.array((1,2,3,4))
# type(a)

d = np.array({"name":"erol", "age": 39}, dtype='str')
type(d)
# Out:
# numpy.ndarray

# %%
arr = np.array((1, 2, 3, 4))
print(arr)
# Out:
# [1 2 3 4]
