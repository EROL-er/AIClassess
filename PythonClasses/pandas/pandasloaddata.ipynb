# %% [markdown]
# # Pandas Data Loading

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.linalg as la
import pandas as pd
import calendar

# %%
df = pd.read_csv('../../Datasets/fromclass/ecommerce_sales_data(1).csv')
df.iloc[0:10, 1:5]
# df.set_index('customer_id')
# Out:
#   customer_id  customer_name           customer_email product_id
# 0   CUST-0225   Ashley Lewis   ashley.lewis@email.com  PROD-5566
# 1   CUST-0293     Angela Lee     angela.lee@email.com  PROD-5706
# 2   CUST-0299    David Davis    david.davis@email.com  PROD-8623
# 3   CUST-0177  Paul Thompson  paul.thompson@email.com  PROD-3154
# 4   CUST-0011   James Harris   james.harris@email.com  PROD-8882
# 5   CUST-0022     Paul Clark     paul.clark@email.com  PROD-8594
# 6   CUST-0101   Andrew Davis   andrew.davis@email.com  PROD-4952
# 7   CUST-0172     John Davis     john.davis@email.com  PROD-1180
# 8   CUST-0047     Paul Jones     paul.jones@email.com  PROD-4634
# 9   CUST-0170  Robert Miller  robert.miller@email.com  PROD-5873
