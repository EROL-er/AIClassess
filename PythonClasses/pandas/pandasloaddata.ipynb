# %% [markdown]
# # Pandas Data Loading

# %%
import pandas as pd
import pandas as pd
import calendar

#%pip install pandas

# %%
df = pd.read_csv('../../Datasets/fromclass/ecommerce_sales_data.csv')
# df.iloc[0:10, 1:5]
# df.set_index('customer_id')
df.describe().T

# df['total_amount'].argmax()

df.loc[[3, 5, 7], ['total_amount']]
df.shape[0]
df.isnull().sum()
df.isnull().mean()*100
c_n = df['customer_name'] if 'customer_name'  not in  df.columns else df.iloc[:,1]
c_n
p = df['price'] if 'price' in df.columns else df.iloc[:,4]
p
# Out:
# 0        19.87
# 1       882.75
# 2        73.08
# 3        49.62
# 4        74.16
#          ...
# 1215    199.45
# 1216    113.35
# 1217    297.50
# 1218     61.17
# 1219    297.33
# Name: price, Length: 1220, dtype: float64

# %%
if all(col in df.columns for col in ['customer_name', 'product_name','price']):
  selected_columns = df[['customer_name', 'product_name','price']]
else:
  selected_columns = df.iloc[:, [1, 2, 4]]

selected_columns
# Out:
#          customer_name       product_name   price
# 0         Ashley Lewis  Business Strategy   19.87
# 1           Angela Lee        Dell Laptop  882.75
# 2          David Davis    Web Development   73.08
# 3        Paul Thompson       Dumbbell Set   49.62
# 4         James Harris      Tennis Racket   74.16
# ...                ...                ...     ...
# 1215       Lisa Taylor             Jacket  199.45
# 1216  Anthony Martinez     Vacuum Cleaner  113.35
# 1217      Mark Ramirez         Bed Sheets  297.50
# 1218      Daniel Jones         Bed Sheets   61.17
# 1219       James Clark        MacBook Pro  297.33
#
# [1220 rows x 3 columns]
