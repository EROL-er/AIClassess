# %%
#install missing package so import resolves
#%pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('../../Datasets/fromclass/ecommerce_sales_data.csv')
a=df['customer_age'].bfill().head(20)
b=df['total_amount'].bfill().head(20)
plt.scatter(b,a)

# %%
x = np.linspace(1, 10, 100)

y1 = np.sin(x)
y2 = np.sin(x + np.pi/4)
y3 = np.sin(x + np.pi/2)

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(x, y1, label='Series 1', linewidth=2) 
ax.plot(x, y2, label='Series 2', linewidth=4) 
ax.plot(x, y3, label='Series 3', linewidth=6)


ax.set_title('Multiple Line Plot Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

ax.legend


plt.tight_layout()
plt.show()
