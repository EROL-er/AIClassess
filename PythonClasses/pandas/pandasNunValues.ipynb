# %%
# %pip install pandas
import pandas as pd
import pandas as pd

# %%
df = pd.read_csv('../../Datasets/fromclass/ecommerce_sales_data.csv')

df_with_missing = df.copy()

# %%
df_with_missing.isna().sum() / len(df_with_missing) * 100
# df_with_missing_row = df_with_missing.dropna(subset='customer_email')
# df_with_missing_row.isna().sum() / len(df_with_missing) * 100
# df_with_missing 
a=df_with_missing.loc[:,['customer_email']]
a
# df_with_missing.loc[:,['customer_email']].sample(20)
# Out:
#                   customer_email
# 0         ashley.lewis@email.com
# 1           angela.lee@email.com
# 2          david.davis@email.com
# 3        paul.thompson@email.com
# 4         james.harris@email.com
# ...                          ...
# 1215       lisa.taylor@email.com
# 1216  anthony.martinez@email.com
# 1217      mark.ramirez@email.com
# 1218      daniel.jones@email.com
# 1219       james.clark@email.com
#
# [1220 rows x 1 columns]

# %%
# c=df_with_missing['customer_email'] = df_with_missing['customer_email'].fillna('nun')
# b=df_with_missing.loc[df_with_missing['customer_email'] =='nun', ['customer_email']]
# df_with_missing.head(1)

# %%
# df_with_missing['customer_email'] = df_with_missing['customer_email'].fillna('nun')
# b=df_with_missing.loc[df_with_missing['customer_email'] =='nun', ['customer_email']]


m={'order_id':0,'`customer_id': 1,'customer_name': 2,'customer_email': 3,'product_id':4,'product_name ':5,'category':6,'brand':7,'price':8, 'quantity':2
}

d = df_with_missing.fillna(value=m)
q=df_with_missing.loc[df_with_missing['customer_email'] ==3, ['customer_email']]
d['category'].sample(1)
# Out:
# 918    Electronics
# Name: category, dtype: object

# %%
f=df_with_missing['price'].mean()
f.round(2)
df_with_missing['customer_email'] = df_with_missing['customer_email'].fillna(f)
y=df_with_missing.loc[df_with_missing['customer_email'] ==f, ['customer_email']]
y
j=df_with_missing.ffill().bfill()

# %%
m = df_with_missing['customer_email'].mode()[0]
df_with_missing['customer_email'] = df_with_missing['customer_email'].fillna(m)
